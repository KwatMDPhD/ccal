# %%
import sys
sys.path.insert(0, '..')
import ccal
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
df = ccal.read_gct('data/ccle_hema/nmf_k9_h.gct')

# %%
'{} bbb'.format('af').strip()
# Out:
# 'af bbb'

# %%
ccal.plot_heatmap(df.iloc[:, :50])
