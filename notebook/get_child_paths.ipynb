# %%
# %load_ext autoreload
# %autoreload 2

# %%
import kraft

# %%
kraft.get_child_paths("..")
# Out:
# ('kraft.egg-info/',
#  'notebook/',
#  '.git/',
#  'kraft/',
#  'README.md',
#  'setup.py',
#  '.gitignore',
#  'kraft.egg-info/PKG-INFO',
#  'kraft.egg-info/SOURCES.txt',
#  'kraft.egg-info/requires.txt',
#  'kraft.egg-info/top_level.txt',
#  'kraft.egg-info/dependency_links.txt',
#  'notebook/.ipynb_checkpoints/',
#  'notebook/score_set.ipynb',
#  'notebook/get_kl.ipynb',
#  'notebook/is_sorted.ipynb',
#  'notebook/cluster.ipynb',
#  'notebook/get_moe.ipynb',
#  'notebook/c2.gmt',
#  'notebook/Untitled.ipynb',
#  'notebook/plot.ipynb',
#  'notebook/ignore_nan_and_function.ipynb',
#  'notebook/infer.ipynb',
#  'notebook/estiamte_density.ipynb',
#  'notebook/binarize.ipynb',
#  'notebook/__init__.ipynb',
#  'notebook/select_extreme.ipynb',
#  'notebook/gps_map.ipynb',
#  'notebook/titanic.tsv',
#  'notebook/clip.ipynb',
#  'notebook/flatten.ipynb',
#  'notebook/get_child_paths.ipynb',
#  'notebook/kras_gps_map.k_x_h_element.tsv',
#  'notebook/factorize_matrix.ipynb',
# ...

# %%
kraft.get_child_paths("..", relative=False)
# Out:
# ('../kraft.egg-info/',
#  '../notebook/',
#  '../.git/',
#  '../kraft/',
#  '../README.md',
#  '../setup.py',
#  '../.gitignore',
#  '../kraft.egg-info/PKG-INFO',
#  '../kraft.egg-info/SOURCES.txt',
#  '../kraft.egg-info/requires.txt',
#  '../kraft.egg-info/top_level.txt',
#  '../kraft.egg-info/dependency_links.txt',
#  '../notebook/.ipynb_checkpoints/',
#  '../notebook/score_set.ipynb',
#  '../notebook/get_kl.ipynb',
#  '../notebook/is_sorted.ipynb',
#  '../notebook/cluster.ipynb',
#  '../notebook/get_moe.ipynb',
#  '../notebook/c2.gmt',
#  '../notebook/Untitled.ipynb',
#  '../notebook/plot.ipynb',
#  '../notebook/ignore_nan_and_function.ipynb',
#  '../notebook/infer.ipynb',
#  '../notebook/estiamte_density.ipynb',
#  '../notebook/binarize.ipynb',
#  '../notebook/__init__.ipynb',
#  '../notebook/select_extreme.ipynb',
#  '../notebook/gps_map.ipynb',
#  '../notebook/titanic.tsv',
#  '../notebook/clip.ipynb',
#  '../notebook/flatten.ipynb',
#  '../notebook/get_child_paths.ipynb',
# ...
