# %%
import sys
sys.path.insert(0, '../../')
import ccal
# %matplotlib inline
# %config InlineBackend.figure_formats = {'svg',}
# Out:
# ===============================================================================
# ==================== Computational Cancer Analysis Library ====================
# ===============================================================================
#
# <10:53:20.887420> Checking dependencies ...
# <10:53:20.893517> Using the following packages:
# <10:53:20.899412> 	matplotlib (v1.5.1)
# <10:53:20.899485> 	numpy (v1.10.4)
# <10:53:20.899517> 	pandas (v0.18.0)
# <10:53:20.899581> 	rpy2 (v2.8.2)
# <10:53:20.899610> 	scikit-learn (v0.17.1)
# <10:53:20.899638> 	scipy (v0.17.0)
# <10:53:20.899668> 	seaborn (v0.7.1)

# %%
nrow, ncol = 3, 3
features = ccal.support.make_random_features(nrow, ncol)
ref = ccal.support.make_random_features(1, ncol)

# %%
ccal.analyze.rank_features_against_reference(features, ref)
# Out:
# <10:53:24.784946> Computing features vs. Feature 0 using ic metric ...
# <10:53:24.785118> Using 3 intersecting columns from features and ref, which have 3 and 3 columns respectively ...
# Bootstrapping to get 0.95 confidence interval ...
# Performing permutation test with 3 permutations ...
# ../../ccal/information.py:84: FutureWarning: in the future, boolean array-likes will be handled as a boolean array index
#   v = v[overlap] + jitters[i]
# <10:53:25.833610> Plotting top 0.95 features vs. ref ...
# <10:53:25.925739> Normalizing continuous features ...
# <10:53:25.928897> Normalizing continuous ref ...
