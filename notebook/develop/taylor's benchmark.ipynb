# %%
import sys
sys.path.insert(0, '../../')
import ccal
# %matplotlib inline
# %config InlineBackend.figure_formats = {'svg',}
# Out:
# ===============================================================================
# ==================== Computational Cancer Analysis Library ====================
# ===============================================================================
# <01:29:15.524314> Checking dependencies ...
# <01:29:15.526432> Using the following packages:
# <01:29:15.528098> 	matplotlib (v1.5.1)
# <01:29:15.528115> 	numpy (v1.10.4)
# <01:29:15.528124> 	pandas (v0.18.0)
# <01:29:15.528145> 	rpy2 (v2.7.9)
# <01:29:15.528154> 	scikit-learn (v0.17.1)
# <01:29:15.528161> 	scipy (v0.17.0)
# <01:29:15.528168> 	seaborn (v0.7.0)

# %% [markdown]
# # Testing 3x30

# %%
nrow, ncol = 3, 30
features = ccal.support.make_random_features(nrow, ncol)
ref = ccal.support.make_random_features(1, ncol)

ccal.analyze.rank_features_against_reference(features, ref)
# Out:
# <01:29:16.371733> Computing features vs. Feature 0 using information_coef metric ...
# <01:29:16.371800> Using 30 intersecting columns from features and ref, which have 30 and 30 columns respectively ...
# <01:29:16.455672> Bootstrapping to get 0.95 confidence interval ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-617a645b441a> in <module>()
#       3 ref = ccal.support.make_random_features(1, ncol)
#       4
# ----> 5 ccal.analyze.rank_features_against_reference(features, ref)
#
# /Users/Kwat/binf/cca/ccal/analyze.py in rank_features_against_reference(features, ref, features_type, ref_type, features_ascending, ref_ascending, ref_sort, metric, n_sampling, confidence, n_perm, title, n_features, rowname_size, output_prefix, figure_type)
#      96     # Compute scores which is sorted by information coefficient
#      97     scores = compute_against_reference(features, ref, metric=metric, ascending=features_ascending,
# ---> 98                                        n_sampling=n_sampling, confidence=confidence, n_perm=n_perm)
#      99     features = features.reindex(scores.index)
#     100
#
# /Users/Kwat/binf/cca/ccal/analyze.py in compute_against_reference(features, ref, metric, ascending, n_sampling, confidence, n_perm)
#     165         # Compute sample score
#     166         for j, (idx, s) in enumerate(sampled_features.iterrows()):
# --> 167             sampled_scores[j, i] = function(s, sampled_ref)
#     168     # Get confidence interval
#     169     z_critical = stats.norm.ppf(q=confidence)
#
# /Users/Kwat/binf/cca/ccal/information.py in information_coefficient(x, y, z, n_grid, vector_data_type, n_perm, adaptive, alpha, perm_alpha)
#      68
#      69     mi = mutual_information(x, y, z=z, n_grid=n_grid,
# ---> 70                             vector_data_types=vector_data_type, bandwidth_scaling=bandwidth_scaling)
#      71     ic_sign = np.sign(rho)
#      72     ic = ic_sign * np.sqrt(1 - np.exp(- 2 * mi))
#
# /Users/Kwat/binf/cca/ccal/information.py in mutual_information(x, y, z, n_grid, vector_data_types, bandwidth_scaling)
#     147     if bandwidth_scaling:
#     148         delta *= bandwidth_scaling
# --> 149     kde = KDEMultivariate(vectors, bw=delta, var_type=vector_data_types)
#     150     p_joint = kde.pdf(grid).reshape(grid_shape) + np.finfo(float).eps
#     151     ds = [grid[1] - grid[0] for grid in grids]
#
# /Applications/anaconda3/lib/python3.5/site-packages/statsmodels/nonparametric/kernel_density.py in __init__(self, data, var_type, bw, defaults)
#     109         self.nobs, self.k_vars = np.shape(self.data)
#     110         if self.nobs <= self.k_vars:
# --> 111             raise ValueError("The number of observations must be larger " \
#     112                              "than the number of variables.")
#     113
#
# ValueError: The number of observations must be larger than the number of variables.

# %% [markdown]
# # Testing 5x5

# %%
nrow, ncol = 5, 5
features = ccal.support.make_random_features(nrow, ncol)
ref = ccal.support.make_random_features(1, ncol)

ccal.analyze.rank_features_against_reference(features, ref)
# Out:
# <11:15:11.825792> Computing features vs. Feature 0 using ic metric ...
# <11:15:11.825919> Using 5 intersecting columns from features and ref, which have 5 and 5 columns respectively ...
# Bootstrapping to get 0.95 confidence interval ...
# Performing permutation test with 3 permutations ...
# ../../ccal/information.py:84: FutureWarning: in the future, boolean array-likes will be handled as a boolean array index
#   v = v[overlap] + jitters[i]
# <11:15:14.235090> Plotting top 0.95 features vs. ref ...
# <11:15:14.240135> Normalizing continuous features ...
# <11:15:14.248843> Normalizing continuous ref ...

# %% [markdown]
# # Testing 20x20

# %%
nrow, ncol = 20, 20
features = ccal.support.make_random_features(nrow, ncol)
ref = ccal.support.make_random_features(1, ncol)

ccal.analyze.rank_features_against_reference(features, ref)
# Out:
# <11:16:54.967477> Computing features vs. Feature 0 using ic metric ...
# <11:16:54.967621> Using 20 intersecting columns from features and ref, which have 20 and 20 columns respectively ...
# Bootstrapping to get 0.95 confidence interval ...
# Performing permutation test with 3 permutations ...
# ../../ccal/information.py:84: FutureWarning: in the future, boolean array-likes will be handled as a boolean array index
#   v = v[overlap] + jitters[i]
# <11:17:04.472031> Plotting top 0.95 features vs. ref ...
# <11:17:04.477200> Normalizing continuous features ...
# <11:17:04.575157> Normalizing continuous ref ...

# %% [markdown]
# # Testing 3x10

# %%
nrow, ncol = 3, 10
features = ccal.support.make_random_features(nrow, ncol)
ref = ccal.support.make_random_features(1, ncol)

ccal.analyze.rank_features_against_reference(features, ref)
# Out:
# <11:19:37.720729> Computing features vs. Feature 0 using ic metric ...
# <11:19:37.720861> Using 10 intersecting columns from features and ref, which have 10 and 10 columns respectively ...
# Bootstrapping to get 0.95 confidence interval ...
# Performing permutation test with 3 permutations ...
# ../../ccal/information.py:84: FutureWarning: in the future, boolean array-likes will be handled as a boolean array index
#   v = v[overlap] + jitters[i]
# <11:19:38.607642> Plotting top 0.95 features vs. ref ...
# <11:19:38.611698> Normalizing continuous features ...
# <11:19:38.617438> Normalizing continuous ref ...

# %% [markdown]
# # Testing 3x4

# %%
nrow, ncol = 3, 4
features = ccal.support.make_random_features(nrow, ncol)
ref = ccal.support.make_random_features(1, ncol)

ccal.analyze.rank_features_against_reference(features, ref)
# Out:
# <11:20:16.013008> Computing features vs. Feature 0 using ic metric ...
# <11:20:16.013145> Using 4 intersecting columns from features and ref, which have 4 and 4 columns respectively ...
# Bootstrapping to get 0.95 confidence interval ...
# Performing permutation test with 3 permutations ...
# ../../ccal/information.py:84: FutureWarning: in the future, boolean array-likes will be handled as a boolean array index
#   v = v[overlap] + jitters[i]
# <11:20:16.967837> Plotting top 0.95 features vs. ref ...
# <11:20:16.973131> Normalizing continuous features ...
# <11:20:16.977478> Normalizing continuous ref ...

# %% [markdown]
# # Testing 20x30

# %%
nrow, ncol = 20, 30
features = ccal.support.make_random_features(nrow, ncol)
ref = ccal.support.make_random_features(1, ncol)

ccal.analyze.rank_features_against_reference(features, ref)
# Out:
# <11:21:34.668907> Computing features vs. Feature 0 using ic metric ...
# <11:21:34.669224> Using 30 intersecting columns from features and ref, which have 30 and 30 columns respectively ...
# Bootstrapping to get 0.95 confidence interval ...
# Performing permutation test with 3 permutations ...
# ../../ccal/information.py:84: FutureWarning: in the future, boolean array-likes will be handled as a boolean array index
#   v = v[overlap] + jitters[i]
# <11:21:44.336329> Plotting top 0.95 features vs. ref ...
# <11:21:44.343070> Normalizing continuous features ...
# <11:21:44.519313> Normalizing continuous ref ...

# %% [markdown]
# # Testing with file

# %%
ref = ccal.support.read_gct('~/Desktop/sampleRef.gct')
feature = ccal.support.read_gct('~/Desktop/sampleFeat.gct')
ccal.analyze.rank_features_against_reference(feature, ref.ix[0,:])
# Out:
# <11:54:52.710972> Computing features vs. BRAF_UP using ic metric ...
# <11:54:52.711280> Using 3 intersecting columns from features and ref, which have 3 and 3 columns respectively ...
# Bootstrapping to get 0.95 confidence interval ...
# Performing permutation test with 3 permutations ...
# ../../ccal/information.py:84: FutureWarning: in the future, boolean array-likes will be handled as a boolean array index
#   v = v[overlap] + jitters[i]
# <11:55:01.285443> Plotting top 0.95 features vs. ref ...
# <11:55:01.296216> Normalizing continuous features ...
# <11:55:01.310436> Normalizing continuous ref ...
