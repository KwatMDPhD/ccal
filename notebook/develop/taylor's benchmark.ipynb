# %%
import sys
sys.path.insert(0, '../../')
import ccal
# %matplotlib inline
# %config InlineBackend.figure_formats = {'svg',}
# Out:
# ===============================================================================
# ==================== Computational Cancer Analysis Library ====================
# ===============================================================================
#
# <16:30:21.919634> Checking dependencies ...
# <16:30:21.924260> Using the following packages:
# <16:30:21.927586> 	matplotlib (v1.5.1)
# <16:30:21.927625> 	numpy (v1.10.4)
# <16:30:21.927642> 	pandas (v0.18.0)
# <16:30:21.927674> 	rpy2 (v2.8.2)
# <16:30:21.927689> 	scikit-learn (v0.17.1)
# <16:30:21.927703> 	scipy (v0.17.0)
# <16:30:21.927719> 	seaborn (v0.7.1)

# %%
f = ccal.support.make_random_features(30, 30)
f
# Out:
#             Element 0  Element 1  Element 2  Element 3  Element 4  Element 5  \
# Feature 0    0.417212   0.730631   0.036038   0.093998   0.832324   0.033355
# Feature 1    0.057486   0.859262   0.291565   0.783001   0.385251   0.185772
# Feature 2    0.602916   0.733869   0.282364   0.176229   0.560292   0.045073
# Feature 3    0.836001   0.566246   0.507215   0.460820   0.997926   0.879587
# Feature 4    0.074551   0.814133   0.519188   0.326259   0.102033   0.514926
# Feature 5    0.368965   0.573138   0.546480   0.483978   0.636361   0.418730
# Feature 6    0.468710   0.541771   0.784607   0.584341   0.112743   0.940927
# Feature 7    0.372184   0.089297   0.715132   0.547151   0.714390   0.180163
# Feature 8    0.322501   0.619643   0.200900   0.562421   0.433700   0.811999
# Feature 9    0.555381   0.247836   0.635582   0.227047   0.944271   0.582676
# Feature 10   0.483686   0.024005   0.816303   0.476800   0.504779   0.346750
# Feature 11   0.365090   0.329486   0.767880   0.393528   0.655640   0.910034
# Feature 12   0.107197   0.158014   0.335571   0.038838   0.921481   0.874040
# Feature 13   0.278628   0.950336   0.235833   0.975683   0.389731   0.051320
# Feature 14   0.196282   0.481382   0.928491   0.106388   0.740629   0.811457
# Feature 15   0.595207   0.903874   0.389607   0.731329   0.677271   0.222302
# Feature 16   0.992382   0.468207   0.019135   0.564671   0.326973   0.230221
# Feature 17   0.543307   0.454506   0.372816   0.050492   0.093914   0.886394
# Feature 18   0.902730   0.739194   0.572143   0.538517   0.275483   0.733835
# Feature 19   0.452003   0.136380   0.174644   0.562584   0.336293   0.675433
# Feature 20   0.976937   0.392996   0.478483   0.070038   0.596958   0.087772
# Feature 21   0.575761   0.368557   0.340529   0.651741   0.903618   0.326387
# Feature 22   0.161134   0.382728   0.765671   0.574822   0.887931   0.159504
# Feature 23   0.874739   0.272520   0.585060   0.227260   0.046201   0.694200
# Feature 24   0.740406   0.911527   0.309722   0.041333   0.642570   0.729930
# Feature 25   0.983929   0.856974   0.645109   0.833913   0.548704   0.302430
# Feature 26   0.658426   0.676842   0.136715   0.755431   0.524683   0.755199
# Feature 27   0.894450   0.318733   0.988784   0.778678   0.333368   0.364162
# Feature 28   0.001636   0.680118   0.972397   0.984617   0.704845   0.152979
# Feature 29   0.980589   0.797019   0.986627   0.612280   0.896417   0.849609
#
#             Element 6  Element 7  Element 8  Element 9     ...      \
# Feature 0    0.087956   0.532799   0.808811   0.903893     ...
# Feature 1    0.844792   0.576130   0.671608   0.891932     ...
# Feature 2    0.320598   0.433806   0.366386   0.721836     ...
# Feature 24    0.826669    0.347862    0.210177    0.115771    0.232697
# Feature 25    0.463677    0.978700    0.143159    0.815564    0.554313
# Feature 26    0.230156    0.848184    0.718026    0.157902    0.989697
# Feature 27    0.209246    0.004609    0.155148    0.545997    0.185652
# Feature 28    0.661360    0.809553    0.561667    0.186840    0.000122
# Feature 29    0.815850    0.938281    0.641041    0.585626    0.251284
#
#             Element 25  Element 26  Element 27  Element 28  Element 29
# Feature 0     0.582275    0.702630    0.196650    0.145961    0.999814
# Feature 1     0.273231    0.123686    0.040141    0.362915    0.793594
# Feature 2     0.011449    0.170789    0.785186    0.025489    0.510743
# Feature 3     0.354513    0.928963    0.981377    0.062851    0.502040
# Feature 4     0.496554    0.688678    0.712669    0.168588    0.019675
# Feature 5     0.544444    0.557576    0.428339    0.815046    0.580088
# Feature 6     0.050659    0.972506    0.377740    0.865055    0.369547
# Feature 7     0.430677    0.651720    0.601703    0.646972    0.206041
# Feature 8     0.339105    0.432842    0.650519    0.741811    0.916747
# Feature 9     0.952487    0.130888    0.119085    0.202987    0.656087
# Feature 10    0.109303    0.209928    0.676973    0.148977    0.024732
# Feature 11    0.588351    0.576190    0.145258    0.184667    0.490329
# Feature 12    0.704763    0.200184    0.599785    0.068738    0.225044
# Feature 13    0.021349    0.390871    0.596786    0.902380    0.801125
# Feature 14    0.215236    0.305604    0.403234    0.673125    0.322023
# Feature 15    0.960021    0.552945    0.485902    0.117770    0.233533
# Feature 16    0.123285    0.591824    0.585726    0.255873    0.314997
# Feature 17    0.747504    0.177062    0.209926    0.986648    0.552700
# Feature 18    0.631045    0.989132    0.108093    0.982620    0.787907
# Feature 19    0.781652    0.686888    0.220862    0.956264    0.004444
# Feature 20    0.182561    0.865348    0.958329    0.733304    0.614440
# Feature 21    0.002332    0.958818    0.394716    0.925609    0.766120
# Feature 22    0.698221    0.967825    0.753671    0.282056    0.694197
# Feature 23    0.465450    0.726252    0.625402    0.477271    0.645429
# Feature 24    0.456469    0.338617    0.857931    0.546106    0.492505
# Feature 25    0.948860    0.683399    0.668297    0.099628    0.964577
# Feature 26    0.278732    0.302999    0.431674    0.012353    0.927889
# Feature 27    0.776799    0.604763    0.046337    0.245972    0.900320
# Feature 28    0.994156    0.330228    0.768798    0.801391    0.451681
# Feature 29    0.323925    0.963897    0.465820    0.501444    0.313123
#
# [30 rows x 30 columns]

# %%
r = ccal.support.make_random_features(2, 30)
r_1_df = r.ix[:1, :]
r_1_s = r.ix[0, :]
ccal.analyze.rank_features_against_reference(f, r_1_s, nperm=3, nsampling=5, output_prefix='/Users/Taylor/Desktop/random_result')
ccal.support.write_gct(f, '/Users/Taylor/Desktop/features.gct')
ccal.support.write_gct(r_1_df, '/Users/Taylor/Desktop/reference.gct')
# Out:
# <16:43:43.220060> Computing features vs. Feature 0 using information_coef metric ...
# <16:43:43.222802> Path /Users/Taylor/Desktop/random_result doesn't exist, creating it ...
# <16:43:43.223205> Using 30 intersecting columns from features and ref, which have 31 and 30 columns respectively ...
# Computing with metric information_coef ...
# Bootstrapping to get 0.95 confidence interval ...
# Performing permutation test with 3 permutations ...
# ../../ccal/information.py:84: FutureWarning: in the future, boolean array-likes will be handled as a boolean array index
#   v = v[overlap] + jitters[i]
# <16:44:03.375320> Saved the result as /Users/Taylor/Desktop/random_result.txt.
# <16:44:03.375413> Plotting top 0 features vs. ref ...
# <16:44:03.384479> Normalizing continuous features ...
# <16:44:03.698128> Normalizing continuous ref ...
# <16:44:07.501882> Saved the figure as /Users/Taylor/Desktop/random_result.png.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-0ba133e7b7c8> in <module>()
#       3 r_1_s = r.ix[0, :]
#       4 ccal.analyze.rank_features_against_reference(f, r_1_s, nperm=3, nsampling=5, output_prefix='/Users/Taylor/Desktop/random_result')
# ----> 5 ccal.support.write_gct(f, '/Users/Taylor/Desktop/features.gct')
#       6 ccal.support.write_gct(r_1_df, '/Users/Taylor/Desktop/reference.gct')
#
# /Users/Taylor/cca/ccal/support.py in write_gct(dataframe, filename, description, index_column)
#     148     else:
#     149         description = dataframe.index
# --> 150     dataframe.insert(0, 'Description', description)
#     151
#     152     with open(filename, 'w') as f:
#
# /Users/Taylor/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    2438         value = self._sanitize_column(column, value)
#    2439         self._data.insert(loc, column, value,
# -> 2440                           allow_duplicates=allow_duplicates)
#    2441
#    2442     def assign(self, **kwargs):
#
# /Users/Taylor/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in insert(self, loc, item, value, allow_duplicates)
#    3443         if not allow_duplicates and item in self.items:
#    3444             # Should this be a different kind of error??
# -> 3445             raise ValueError('cannot insert %s, already exists' % item)
#    3446
#    3447         if not isinstance(loc, int):
#
# ValueError: cannot insert Description, already exists

# %% [markdown]
# # Testing 3x30

# %%
nrow, ncol = 3, 30
features = ccal.support.make_random_features(nrow, ncol)
ref = ccal.support.make_random_features(1, ncol)

ccal.analyze.rank_features_against_reference(features, ref)

# %% [markdown]
# # Testing 5x5

# %%
nrow, ncol = 5, 5
features = ccal.support.make_random_features(nrow, ncol)
ref = ccal.support.make_random_features(1, ncol)

ccal.analyze.rank_features_against_reference(features, ref)

# %% [markdown]
# # Testing 20x20

# %%
nrow, ncol = 20, 20
features = ccal.support.make_random_features(nrow, ncol)
ref = ccal.support.make_random_features(1, ncol)

ccal.analyze.rank_features_against_reference(features, ref)

# %% [markdown]
# # Testing 3x10

# %%
nrow, ncol = 3, 10
features = ccal.support.make_random_features(nrow, ncol)
ref = ccal.support.make_random_features(1, ncol)

ccal.analyze.rank_features_against_reference(features, ref)

# %% [markdown]
# # Testing 3x4

# %%
nrow, ncol = 3, 4
features = ccal.support.make_random_features(nrow, ncol)
ref = ccal.support.make_random_features(1, ncol)

ccal.analyze.rank_features_against_reference(features, ref)

# %% [markdown]
# # Testing 20x30

# %%
nrow, ncol = 20, 30
features = ccal.support.make_random_features(nrow, ncol)
ref = ccal.support.make_random_features(1, ncol)

ccal.analyze.rank_features_against_reference(features, ref)

# %%
ccal.support.write_gct(features, '~/Desktop/TestFeature')

# %%
features

# %% [markdown]
# # Testing with file

# %%
ref = ccal.support.read_gct('~/Desktop/sampleRef.gct')
feature = ccal.support.read_gct('~/Desktop/sampleFeat.gct')
ccal.analyze.rank_features_against_reference(feature, ref.ix[0,:])

# %%
ref

# %%
feature
