# %% [markdown]
# <hr style="border: none; border-bottom: 1px solid pink;">
# # Playground Test
# <hr style="border: none; border-bottom: 1px solid pink;">

# %%
#Just playing with some things here
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_formats = {'svg',}

x = [0,1,2,3,4,5]
y = [2,4,6,8,10,12]

plt.plot(x,y, 'ro')
plt.ylabel("Y axis")
plt.xlabel("X axis")
#plt.show()

# %%
# %matplotlib notebook
# %matplotlib inline
#%config InlineBackend.figure_formats = {'svg',}

import sys
sys.path.insert(0, '../../')
import ccal
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib 


# Make Random plot
#nrow, ncol = 5, 5
#features = ccal.support.make_random_features(nrow,ncol)
#ref = ccal.support.make_random_features(1,ncol)
matrix = np.random.randn(10, 7)
df = pd.DataFrame(matrix)
print(df)
print(matrix)
ax = sns.heatmap(matrix)

#p = HeatMap(df, width = 5)

# %%
#Experimenting with plotpy
import numpy as np
import pandas as pd
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

plotly.tools.set_credentials_file(username='robotgoat', api_key='xg611gtnfp')

matrix = np.random.randn(10, 7)
df = pd.DataFrame(matrix)

data = [go.Heatmap(
        z = matrix
    )
        ]
py.iplot(data, filename='random heatmap')

# %%
#Studpid Bokeh 
import pandas 
import numpy as np
from bokeh.charts import HeatMap, output_file, show

data = ([4, 5, 8],
        [1, 2, 3]
       )
mx = np.random.randn(10,5)
arr = [np.random.randn(6)]
data
hm = HeatMap(data, y='bll', x='lalal')
#show(hm)

# %%
import pandas 
import numpy as np

from math import pi

from bokeh.models import HoverTool
from bokeh.plotting import ColumnDataSource, figure, show, output_file
from bokeh.sampledata.unemployment1948 import data

matrix = np.random.randn(10, 7)
df = pd.DataFrame(matrix)

#data['Year'] = [str(x) for x in data['Year']]
print(df)
print(df[0])
# Out:
#           0         1         2         3         4         5         6
# 0 -0.579506 -0.626331 -1.023905  0.688114 -0.205271  0.058177 -1.383724
# 1  0.109309  0.234019 -1.760614 -0.641414 -0.391634  0.426539  0.383612
# 2  0.025714 -0.330435  0.977858  0.437282 -1.158170 -0.312077 -0.165862
# 3  1.004355 -0.620978 -0.503242 -0.180455 -1.345621  0.989330 -1.208611
# 4  0.198187  0.018669 -0.957768  0.141159  0.369478 -1.034915 -1.966728
# 5 -1.425356  0.617570 -1.175543  0.921604 -0.182252  0.894617  0.684368
# 6 -1.412122 -0.652061  0.246624 -0.573680 -0.247363  0.434534  1.005319
# 7 -0.092833 -1.258216  1.854821  0.849575  0.898506  0.393756 -0.322148
# 8  0.087460  0.506607  0.210229 -0.151414 -1.308065 -0.242840 -0.309482
# 9 -0.789817  0.926166 -1.205483 -0.680034  0.006639 -0.419661 -0.547652
# 0   -0.579506
# 1    0.109309
# 2    0.025714
# 3    1.004355
# 4    0.198187
# 5   -1.425356
# 6   -1.412122
# 7   -0.092833
# 8    0.087460
# 9   -0.789817
# Name: 0, dtype: float64

# %% [markdown]
# # Modifing visualize.py's plot_feature_and_reference function

# %%
import sys
sys.path.insert(0, '../../')
import ccal
# %matplotlib inline
# %config InlineBackend.figure_formats = {'svg',}

#first feature
features1 = ccal.support.read_gct('C:/Users/GravityGoose/Documents/MyStuff/Cancer Center/HNSCC_datasets/HNSCC_RPPA.v1.gct') 

#reference 
ref1 = ccal.support.read_gct('C:/Users/GravityGoose/Documents/MyStuff/Cancer Center/Output/HNSCC_create_component_H_matrix.gct')
ref1
# Out:
#           TCGA.4P.AA8J  TCGA.BA.4074  TCGA.BA.4075  TCGA.BA.4076  \
# CompC1_9   1160.819903   1403.525126   1039.332427    710.367844
# CompC2_9   1467.844096   3794.982658   4407.203227   2490.187585
# CompC3_9   2522.257810    825.835369   1099.829634   1685.108349
# CompC4_9    221.187012     20.291049    319.881752   1698.300066
# CompC5_9   1235.369371    822.041337    570.643438     58.874425
# CompC6_9   1989.403650    933.219861    653.139491   1071.134963
# CompC7_9   1551.950280    671.430573    975.160118     28.874951
# CompC8_9     58.218303    269.529457    432.734256    303.069532
# CompC9_9      0.312274    893.169734    167.651085   1329.163110
#
#           TCGA.BA.4077  TCGA.BA.4078  TCGA.BA.5149  TCGA.BA.5151  \
# CompC1_9   1123.150248   2085.408623     14.808631      0.026430
# CompC2_9   1077.392787    229.989184   3437.467159   1869.622840
# CompC3_9    925.724137    485.568719    317.320777    746.848152
# ...
