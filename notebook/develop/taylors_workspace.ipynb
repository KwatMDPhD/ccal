# %% [markdown]
# <hr style="border: none; border-bottom: 1px solid blue;">
#
# # Important Features of KRAS Oncogene Components:
# #### Author: Taylor Cavazos
# <hr style="border: none; border-bottom: 1px solid blue;">

# %%
import sys
sys.path.insert(0, '../../')
import ccal
# %matplotlib inline
# %config InlineBackend.figure_formats = {'svg',}
from IPython.display import Image
# Out:
# ...
# ==================== Computational Cancer Analysis Library ====================
# ...
# <15:15:40> Checking dependencies ...
# <15:15:40> Using the following packages:
# <15:15:40> 	matplotlib (v1.5.1)
# <15:15:40> 	numpy (v1.10.4)
# <15:15:40> 	pandas (v0.18.0)
# <15:15:40> 	rpy2 (v2.8.2)
# <15:15:40> 	scikit-learn (v0.17.1)
# <15:15:40> 	scipy (v0.17.0)
# <15:15:40> 	seaborn (v0.7.1)

# %% [markdown]
# <hr style="border: none; border-bottom: 1px solid blue;">
# ### KRAS Component 6: SOX10
# <hr style="border: none; border-bottom: 1px solid blue;">

# %% [markdown]
#  __Reading oncogenetic target and feature files...__

# %%
ref = ccal.support.read_gct("/Users/Taylor/Documents/Research/Tamayo/Datasets/CCLE.rpkm.v2.SELECTED_SIGNATURES.v2.gct").ix["KRAS_SALE_Late_Comp_C6_9", :]
gene_expression = ccal.support.read_gct("/Users/Taylor/Documents/Research/Tamayo/Datasets/ccle_rpkm_v2.gct")
RNAi = ccal.support.read_gct("/Users/Taylor/Documents/Research/Tamayo/Datasets/Achilles_Combined_55_98_scaledzmad.v2.gct")

# %% [markdown]
# __Ranking Gene Expression against KRAS C6...__

# %%
ccal.analyze.rank_features_against_reference(features=gene_expression, ref=ref, title="KRASC6 VS Gene Expression")

# %% [markdown]
# __Ranking Gene Dependency against KRAS C6...__

# %%
ccal.analyze.rank_features_against_reference(features=RNAi, ref=ref, title="KRASC6 VS Gene Dependency")

# %%
file = "/Users/Taylor/Documents/Research/Tamayo/KRAS components 1-9/KRAS_SALE_Late_Comp_C6_9/SOX10.png"
print("EXPRESSION OF SOX10- 'A Newly Developed Mouse Monoclonal SOX10 is a Highly Sensitive Marker for Malignant Melanoma'")
Image(filename=file)
# Out:
# EXPRESSION OF SOX10- 'A Newly Developed Mouse Monoclonal SOX10 is a Highly Sensitive Marker for Malignant Melanoma'

# %%
file = "/Users/Taylor/Documents/Research/Tamayo/KRAS components 1-9/KRAS_SALE_Late_Comp_C6_9/SOX10_connections.png"
print("SOX10 Interactions- 'GIANT: Genome-scale Integrated Analysis'")
Image(filename=file)
# Out:
# SOX10 Interactions- 'GIANT: Genome-scale Integrated Analysis'

# %% [markdown]
# __Paper on SOX10 and effects of inhibition:__
#
# [SOX10 promotes melanoma cell invasion by regulating melanoma inhibitor activity](http://www.ncbi.nlm.nih.gov/pubmed/24608986)
