# %%
import sys
sys.path.insert(0, '../../')
import ccal
# %matplotlib inline
# %config InlineBackend.figure_formats = {'svg',}

# %% [markdown]
# ## Read reference and features datasets

# %%
features1 = ccal.support.read_gct('/Users/tamayo/UCSD_2015/signatures/demo/Protein_All.gct') 
features2 = ccal.support.read_gct('/Users/tamayo/UCSD_2015/signatures/demo/Pathways_All.gct')
features3 = ccal.support.read_gct('/Users/tamayo/UCSD_2015/signatures/demo/MUT_All.gct')
refs1 = ccal.support.read_gct('/Users/tamayo/UCSD_2015/signatures/demo/KRAS_comp_HN.gct').ix[:1, :]  
refs2 = ccal.support.read_gct('/Users/tamayo/UCSD_2015/signatures/demo/KRAS_comp_ALL.gct').ix[:1, :] 
refs3 = ccal.support.read_gct('/Users/tamayo/UCSD_2015/signatures/demo/KRAS_comp_HN2.gct').ix[:1, :] 
refs4 = ccal.support.read_gct('/Users/tamayo/UCSD_2015/signatures/demo/MUT_All.gct').ix[:1, :] 
refs5 = ccal.support.read_gct('/Users/tamayo/UCSD_2015/signatures/demo/MUT_10.gct').ix[:1, :] 
refs6 = ccal.support.read_gct('/Users/tamayo/UCSD_2015/signatures/demo/KRAS_states.gct').ix[:1, :] 
out_file = '/Users/tamayo/UCSD_2015/signatures/test.pdf'

# %% [markdown]
# ## Continuous ref and features, small number of rows

# %%
ccal.analyze.rank_features_against_references(features1, refs1, 'information_coeff', sort_ref=True, n_features=1, 
                                              out_file=out_file, title='KRAS C1 vs. Protein Expression')

# %% [markdown]
# ## Continuous ref and features, medium number of rows

# %%
ccal.analyze.rank_features_against_references(features1, refs1, 'information_coeff', sort_ref=True, n_features=5, 
                                              out_file=out_file, title='KRAS C1 vs. Protein Expression')

# %% [markdown]
# ## Continuous ref and features, small number of rows, inverse sorting

# %%
ccal.analyze.rank_features_against_references(features1, refs1, 'information_coeff', sort_ref=True, n_features=5, 
                                 direction = 'neg', out_file=out_file, title='KRAS C1 vs. Protein Expression')

# %% [markdown]
# ## Continuous ref and features, large number of columns

# %%
ccal.analyze.rank_features_against_references(features1, refs2, 'information_coeff', sort_ref=True, n_features=5, 
                                              out_file=out_file, title='KRAS C1 vs. Protein Expression')

# %% [markdown]
# ## Continuous ref and features, small number of columns and rows

# %%
ccal.analyze.rank_features_against_references(features1, refs3, 'information_coeff', sort_ref=True, n_features=5, 
                                              out_file=out_file, title='KRAS C1 vs. Protein Expression')

# %% [markdown]
# ## Binary ref, continuous features

# %%
ccal.analyze.rank_features_against_references(features1, refs5, 'information_coeff', sort_ref=True, n_features=3, 
                                  ref_type='binary', out_file=out_file, title='KRAS C1 vs. Protein Expression')

# %%
ccal.analyze.rank_features_against_references(features1, refs4, 'information_coeff', sort_ref=True, n_features=3, 
                                 ref_type='binary', out_file=out_file, title='KRAS C1 vs. Protein Expression')

# %%
refs6
# Out:
#                  A549_LUNG AGS_STOMACH ASPC1_PANCREAS CAL62_THYROID  \
# numerical.states         1           2              1             1
#
#                  CALU1_LUNG CALU6_LUNG CAPAN1_PANCREAS CAPAN2_PANCREAS  \
# numerical.states          1          1               3               3
#
#                  CFPAC1_PANCREAS CL11_LARGE_INTESTINE  \
# numerical.states               3                    2
#
#                               ...              T3M10_LUNG T3M4_PANCREAS  \
# numerical.states              ...                       3             3
#
#                  T84_LARGE_INTESTINE TCCPAN2_PANCREAS TEN_ENDOMETRIUM  \
# numerical.states                   2                1               2
#
#                  TGBC11TKB_STOMACH TOV21G_OVARY UMUC3_URINARY_TRACT  \
# numerical.states                 2            1                   1
#
#                  YAPC_PANCREAS YD8_UPPER_AERODIGESTIVE_TRACT
# numerical.states             3                             1
#
# ...

# %%
ccal.analyze.rank_features_against_references(features1, refs6, 'information_coeff', sort_ref=True, n_features=5, 
                                ref_type='categorical', out_file=out_file, title='KRAS C1 vs. Protein Expression')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-87e174acb63c> in <module>()
#       1 ccal.analyze.rank_features_against_references(features1, refs6, 'information_coeff', sort_ref=True, n_features=5,
# ----> 2                                 ref_type='categorical', out_file=out_file, title='KRAS C1 vs. Protein Expression')
#
# /Users/tamayo/cca/ccal/analyze.py in rank_features_against_references(features, refs, metric, ref_type, feat_type, direction, sort_ref, n_features, rowname_size, out_file, title)
#      90
#      91         # Compute scores, join them in features, and rank features based on scores
# ---> 92         scores = compute_against_reference(features, ref, metric)
#      93
#      94         # Normalize
#
# /Users/tamayo/cca/ccal/analyze.py in compute_against_reference(features, ref, metric)
# ...

# %% [markdown]
# ## Binary features, small number of columns

# %%
#ccal.analyze.rank_features_against_references(features3, refs3, 'information_coeff', sort_ref=True, n_features=5, 
#                                     feat_type='binary', out_file=out_file, title='KRAS C1 vs. Protein Expression')
