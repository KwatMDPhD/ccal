# %%
import sys
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sys.path.insert(0, os.environ['KZ_CODE'])
from kz_code import quantile

from library.ccba import nmf_and_score
from library.visualize import plot_nmf_result, plot_nmf_scores
# %matplotlib inline
# Out:
# <17:42:08.571770> Checking dependencies ...
# <17:42:08.574132> Using the following packages:
# <17:42:08.575909> 	matplotlib v1.5.1
# <17:42:08.575928> 	numpy v1.10.4
# <17:42:08.575937> 	pandas v0.18.0
# <17:42:08.575958> 	rpy2 v2.7.9
# <17:42:08.575967> 	scikit-learn v0.17.1
# <17:42:08.575974> 	scipy v0.17.0
# <17:42:08.575981> 	seaborn v0.7.0

# %%
# Read gene expression matrix
gene_x_sample_df = pd.read_csv('data/GES24759/GSE24759_series_matrix.txt', sep='\t', comment='!', index_col=0)
print('gene_x_sample_df.shape: {}'.format(gene_x_sample_df.shape))

plt.figure(figsize=(30, 20))
ax = sns.heatmap(gene_x_sample_df, cmap='bwr', xticklabels=False, yticklabels=False)
ax.set(xlabel='Sample', ylabel='Gene')
# Out:
# gene_x_sample_df.shape: (22944, 211)
# [<matplotlib.text.Text at 0x11a6ed5f8>, <matplotlib.text.Text at 0x11a6dc358>]

# %%
# NMF and select k
ks = [5, 6]  # Ks from which to select k
nmf_results, scores = nmf_and_score(gene_x_sample_df, ks, method='cophenetic_correlation')
# Out:
# <17:35:37.164619> Computing clustering score for k=5 using method cophenetic_correlation ...
# <17:35:37.164665> Running NMF #0 (total number of assignments=20) ...
# <17:35:37.164676> Perfomring NMF with k=5 ...
# <17:35:38.410121> Running NMF #1 (total number of assignments=20) ...
# <17:35:38.410194> Perfomring NMF with k=5 ...
# <17:35:39.663102> Running NMF #2 (total number of assignments=20) ...
# <17:35:39.663172> Perfomring NMF with k=5 ...
# <17:35:40.931438> Running NMF #3 (total number of assignments=20) ...
# <17:35:40.931509> Perfomring NMF with k=5 ...
# <17:35:42.181259> Running NMF #4 (total number of assignments=20) ...
# <17:35:42.181333> Perfomring NMF with k=5 ...
# <17:35:43.824394> Running NMF #5 (total number of assignments=20) ...
# <17:35:43.824502> Perfomring NMF with k=5 ...
# <17:35:47.148103> Running NMF #6 (total number of assignments=20) ...
# <17:35:47.148220> Perfomring NMF with k=5 ...
# <17:35:50.699721> Running NMF #7 (total number of assignments=20) ...
# <17:35:50.699829> Perfomring NMF with k=5 ...
# <17:35:55.234394> Running NMF #8 (total number of assignments=20) ...
# <17:35:55.234571> Perfomring NMF with k=5 ...
# <17:35:59.232336> Running NMF #9 (total number of assignments=20) ...
# <17:35:59.232452> Perfomring NMF with k=5 ...
# <17:36:02.496826> Running NMF #10 (total number of assignments=20) ...
# <17:36:02.497174> Perfomring NMF with k=5 ...
# <17:36:05.869209> Running NMF #11 (total number of assignments=20) ...
# <17:36:05.869320> Perfomring NMF with k=5 ...
# <17:36:10.386919> Running NMF #12 (total number of assignments=20) ...
# <17:36:10.387037> Perfomring NMF with k=5 ...
# <17:36:14.316704> Running NMF #13 (total number of assignments=20) ...
# <17:36:14.316811> Perfomring NMF with k=5 ...
# <17:36:17.782864> Running NMF #14 (total number of assignments=20) ...
# <17:36:17.782977> Perfomring NMF with k=5 ...
# <17:36:21.375211> Running NMF #15 (total number of assignments=20) ...
# <17:36:21.375327> Perfomring NMF with k=5 ...
# <17:36:25.339095> Running NMF #16 (total number of assignments=20) ...
# <17:36:25.339200> Perfomring NMF with k=5 ...
# <17:36:29.911370> Running NMF #17 (total number of assignments=20) ...
# <17:36:29.911480> Perfomring NMF with k=5 ...
# <17:36:34.045808> Running NMF #18 (total number of assignments=20) ...
# <17:36:34.045908> Perfomring NMF with k=5 ...
# <17:36:38.201971> Running NMF #19 (total number of assignments=20) ...
# <17:36:38.202074> Perfomring NMF with k=5 ...
# <17:36:43.450189> Computing the cophenetic correlation coefficient ...
# <17:36:43.475857> Score for k=5: 0.7353152436869101
# <17:36:43.475908> Computing clustering score for k=6 using method cophenetic_correlation ...
# <17:36:43.475946> Running NMF #0 (total number of assignments=20) ...
# <17:36:43.475974> Perfomring NMF with k=6 ...
# <17:36:48.462584> Running NMF #1 (total number of assignments=20) ...
# <17:36:48.462694> Perfomring NMF with k=6 ...
# <17:36:53.913495> Running NMF #2 (total number of assignments=20) ...
# <17:36:53.913613> Perfomring NMF with k=6 ...
# <17:36:59.402363> Running NMF #3 (total number of assignments=20) ...
# <17:36:59.402459> Perfomring NMF with k=6 ...
# <17:37:04.508675> Running NMF #4 (total number of assignments=20) ...
# <17:37:04.508781> Perfomring NMF with k=6 ...
# <17:37:09.381970> Running NMF #5 (total number of assignments=20) ...
# <17:37:09.382076> Perfomring NMF with k=6 ...
# <17:37:14.217528> Running NMF #6 (total number of assignments=20) ...
# <17:37:14.217674> Perfomring NMF with k=6 ...
# <17:37:19.320466> Running NMF #7 (total number of assignments=20) ...
# <17:37:19.320572> Perfomring NMF with k=6 ...
# <17:37:24.131953> Running NMF #8 (total number of assignments=20) ...
# <17:37:24.132055> Perfomring NMF with k=6 ...
# <17:37:27.230473> Running NMF #9 (total number of assignments=20) ...
# <17:37:27.230578> Perfomring NMF with k=6 ...
# <17:37:30.663871> Running NMF #10 (total number of assignments=20) ...
# <17:37:30.663971> Perfomring NMF with k=6 ...
# <17:37:32.320797> Running NMF #11 (total number of assignments=20) ...
# <17:37:32.320875> Perfomring NMF with k=6 ...
# <17:37:33.985456> Running NMF #12 (total number of assignments=20) ...
# <17:37:33.985552> Perfomring NMF with k=6 ...
# <17:37:35.633237> Running NMF #13 (total number of assignments=20) ...
# <17:37:35.633320> Perfomring NMF with k=6 ...
# <17:37:37.331576> Running NMF #14 (total number of assignments=20) ...
# <17:37:37.331658> Perfomring NMF with k=6 ...
# <17:37:39.000944> Running NMF #15 (total number of assignments=20) ...
# <17:37:39.001057> Perfomring NMF with k=6 ...
# <17:37:40.679461> Running NMF #16 (total number of assignments=20) ...
# <17:37:40.679539> Perfomring NMF with k=6 ...
# <17:37:42.304470> Running NMF #17 (total number of assignments=20) ...
# <17:37:42.304550> Perfomring NMF with k=6 ...
# <17:37:44.323765> Running NMF #18 (total number of assignments=20) ...
# <17:37:44.323848> Perfomring NMF with k=6 ...
# <17:37:45.898767> Running NMF #19 (total number of assignments=20) ...
# <17:37:45.898845> Perfomring NMF with k=6 ...
# <17:37:47.599381> Computing the cophenetic correlation coefficient ...
# <17:37:47.614929> Score for k=6: 0.7823668480082303

# %%
plot_nmf_scores(scores)

# %%
# Plot W and H matrices
k = 6
plot_nmf_result(nmf_results, 6)

# %%
# Get gene information
with open('data/GES24759/GSE24759_family.soft') as f:
    gene_info = {}
    parse_errors = {}
    gene_symbol_errors = {}
    parse = False
    for i, line in enumerate(f.readlines()):
        line = line.strip()
        if not parse:
            if line == '!platform_table_begin':
                parse = True
                print('Start parsing at line {}'.format(i))
        else:
            if line == '!platform_table_end':
                print('Stop parsing at line {}'.format(i))
                parse = False
                break
            else:
                split = line.split('\t')
                try:
                    if (split[8] == '' or split[8] =='NA'):
                        gene_symbol_errors[split[0]] = line
                        continue
                    elif split[0] in gene_info:
                        print('Duplicate at {}'.format(split[0]))
                    else:
                        gene_info[split[0]] = {'gene_title':split[7],
                                               'gene_symbol':split[8].split(' /// '),
                                               'entrez_gene':split[9],
                                               'refseq':split[10].split(' /// ')}
                except:
                    parse_errors[split[0]] = line
    print('Parse error: {}'.format(len(parse_errors)))
    print('Gene symbol error {}'.format(len(gene_symbol_errors)))
# Out:
# Start parsing at line 277
# Stop parsing at line 23223
# Parse error: 1173
# Gene symbol error 741

# %%
# TODO: figure out why the number of passing values are the same for other col in W
top_genes = {}  # dictionary(key: component; value: top genes)

percentile = 0.99
for i in range(nmf_results[k]['W'].shape[1]):
    name = 'k{}c{}'.format(k, i)
    print('Analyzing {} ...'.format(name))
    
    top_genes[name] = set()
    
    col = nmf_results[k]['W'][:, i]
    threshold = quantile(col, 100/((1-percentile)*100))[-1]
    indices_passing_threshold = np.nonzero(np.greater_equal(col, threshold)*col)[0]
    print('{} genes above {} percentile threshold.'.format(len(indices_passing_threshold), percentile*100))

    for gene in gene_x_sample_df.index[indices_passing_threshold]:
        if gene in gene_info:
            top_genes[name].update(set(gene_info[gene]['gene_symbol']))
        elif gene in parse_errors:
            print('Parse error at {}'.format(gene))
        elif gene in gene_symbol_errors:
            print('Gene symbol error at {}'.format(gene))
        else:
            print('Unknown error at {}'.format(gene))
# Out:
# Analyzing k6c0 ...
# 229 genes above 99.0 percentile threshold.
# Parse error at 212560_at
# Parse error at 212764_at
# Parse error at 213158_at
# Parse error at 215450_at
# Parse error at 217554_at
# Gene symbol error at HC-AL049987_at
# Gene symbol error at HC-L41887_at
# Gene symbol error at HC-M37033_at
# Analyzing k6c1 ...
# 229 genes above 99.0 percentile threshold.
# Gene symbol error at 212044_s_at
# Parse error at 216246_at
# Gene symbol error at HC-X76732_at
# Analyzing k6c2 ...
# 229 genes above 99.0 percentile threshold.
# Gene symbol error at HC-D87127_at
# Analyzing k6c3 ...
# 229 genes above 99.0 percentile threshold.
# Parse error at 213839_at
# Parse error at 214836_x_at
# Parse error at 215176_x_at
# Parse error at 217257_at
# Gene symbol error at HC-M37033_at
# Analyzing k6c4 ...
# 229 genes above 99.0 percentile threshold.
# Parse error at 213817_at
# Analyzing k6c5 ...
# 229 genes above 99.0 percentile threshold.
# Parse error at 208192_at
# Parse error at 208529_at
# Parse error at 211617_at
# Parse error at 214809_at
# Parse error at 215014_at
# Parse error at 215725_at
# Parse error at 216556_x_at
# Parse error at 216575_at
# Parse error at 216808_at
# Parse error at 216875_x_at
# Parse error at 217210_at
# Parse error at 217306_at
# Parse error at 217386_at
# Parse error at 217401_at
# Parse error at 217688_at
# Parse error at 220396_at
# Parse error at 220833_at
# Parse error at 220837_at
# Parse error at 220854_at
# Parse error at 220893_at
# Gene symbol error at AFFX-CreXcopy12-3_at
# Gene symbol error at AFFX-CreXcopy21-3_at
# Gene symbol error at AFFX-CreXcopy22-3_at
# Gene symbol error at AFFX-CreXcopy35-3_at
# Gene symbol error at AFFX-CreXcopy36-3_at
# Gene symbol error at AFFX-CreXcopy41-3_at
# Gene symbol error at AFFX-CreXcopy42-3_at
# Gene symbol error at AFFX-CreXcopy44-3_at
# Gene symbol error at AFFX-CreXcopy45-3_at
# Gene symbol error at AFFX-CreXcopy46-3_at
# Gene symbol error at AFFX-CreXcopy47-3_at
# Gene symbol error at AFFX-CreXcopy48-3_at
# Gene symbol error at AFFX-CreXcopy49-3_at
# Gene symbol error at AFFX-CreXcopy7-3_at
# Gene symbol error at AFFX-CreXcopy8-3_at
# Parse error at AFFX-r2-P1-cre-3_at

# %%
for k, v in top_genes.items():
    print('\n\n*** {} ***'.format(k))
    for g in v:
        print('{}'.format(g))
# Out:
# *** k6c0 ***
# ARHGEF6
# NCBP2
# RPL22
# BTN3A2
# TRBV3-1
# ANGEL2
# VDP
# RYK
# PTBP2
# FNDC3A
# KIAA0179
# ECOP
# CBWD3
# ZFP36L2
# MGC8902
# ITGA6
# RPL13
# H3F3B
# DPH5
# FUS
# C14orf138
# FOXO1A
# BTN3A3
# TRBC1
# LYRIC
# ITPKB
# IFI16
# BTN3A1
# FNBP1
# AG1
# CD52
# VPS13C
# DYRK2
# MKL2
# ATM
# TORC3
# LOC200030
# RPL3
# DDX50
# SLC38A1
# TNPO1
# KIAA1076
# MTMR1
# TRIB2
# GOLGA8B
# EP400
# SMCHD1
# RPS19
# TBC1D4
# FNBP4
# ZMYND11
# SMAD3
# FLJ20485
# ARHGEF3
# GMFG
# DDB2
# PORIMIN
# TNFAIP8
# ADD3
# MGA
# PRKD3
