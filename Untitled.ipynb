# %%
import numpy as np
import pandas as pd

# %%
m = pd.DataFrame(np.random.random_sample((10, 10)))

# %%
import matplotlib.pyplot as mpl
import seaborn as sns

# %%
# %matplotlib inline

# %%
sns.heatmap(m, xticklabels=False, yticklabels=False)
sns.clustermap(m, xticklabels=False, yticklabels=False)
# Out:
# /home/k/Jumis/tools/anaconda/lib/python3.6/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
rs = dendrogram(linkage(m[cs], method='average'), no_plot=True)['leaves']
print(rs)
sns.heatmap(m.iloc[rs,:])
# Out:
# [3, 5, 7, 2, 4, 9, 0, 8, 1, 6]

# %%
cs = dendrogram(linkage(m.T, method='average'), no_plot=True)['leaves']
print(cs)
sns.heatmap(m.iloc[rs, cs])
# Out:
# [8, 9, 1, 3, 2, 4, 7, 5, 0, 6]

# %%
sns.clustermap(m.iloc[rs, cs])
# Out:
# /home/k/Jumis/tools/anaconda/lib/python3.6/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
