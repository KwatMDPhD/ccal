# %% [markdown]
# # This is a environment to test, prototype, and develop CCBA libraries.

# %%
#import sys
#sys.path.append('/path/to/ccba')
from library.ccba import *
# %matplotlib inline
# Out:
# Using the following packages:
# matplotlib v1.5.1
# numpy v1.10.4
# pandas v0.18.0
# rpy2 v2.7.9
# scikit-learn v0.17.1
# seaborn v0.7.0

# %%
## Make test data
nrow = 10
ncol = 50
ref = np.random.rand(ncol)
df = pd.DataFrame(np.random.random((nrow, ncol)))
df.index = ['GENE {}'.format(i) for i in range(nrow)]
df
# Out:
#               0         1         2         3         4         5         6   \
# GENE 0  0.065554  0.520584  0.082240  0.557351  0.337438  0.923675  0.863293
# GENE 1  0.209384  0.198788  0.514250  0.552141  0.729965  0.350137  0.108133
# GENE 2  0.438793  0.280104  0.427109  0.099782  0.321787  0.203740  0.230837
# GENE 3  0.319244  0.798370  0.407908  0.686083  0.578868  0.178926  0.425186
# GENE 4  0.543821  0.205172  0.120370  0.272671  0.963634  0.778711  0.719820
# GENE 5  0.683285  0.763376  0.209523  0.009912  0.350395  0.691792  0.920563
# GENE 6  0.312430  0.970988  0.888704  0.655395  0.940515  0.585171  0.240927
# GENE 7  0.764194  0.174020  0.672469  0.210634  0.944184  0.775402  0.745930
# GENE 8  0.355902  0.688526  0.619055  0.321953  0.340617  0.770059  0.789877
# GENE 9  0.001189  0.109190  0.181331  0.681380  0.524346  0.350987  0.437922
#
#               7         8         9     ...           40        41        42  \
# GENE 0  0.740283  0.606594  0.119986    ...     0.423999  0.322477  0.190488
# GENE 1  0.371679  0.391205  0.694259    ...     0.011876  0.202530  0.225980
# GENE 2  0.007691  0.113219  0.477371    ...     0.961607  0.731202  0.804073
# GENE 3  0.867110  0.849129  0.192770    ...     0.699113  0.287257  0.146995
# GENE 4  0.930305  0.756041  0.742528    ...     0.087490  0.863458  0.896710
# GENE 5  0.795134  0.352254  0.173002    ...     0.892832  0.973612  0.264334
# GENE 6  0.464866  0.776756  0.852242    ...     0.308421  0.001018  0.175198
# GENE 7  0.850548  0.887453  0.995703    ...     0.908093  0.672547  0.193776
# GENE 8  0.672064  0.400925  0.710287    ...     0.141985  0.905656  0.883331
# GENE 9  0.724911  0.125157  0.855072    ...     0.819972  0.465344  0.373536
#
#               43        44        45        46        47        48        49
# GENE 0  0.182742  0.283495  0.404277  0.086596  0.502298  0.471192  0.491010
# GENE 1  0.262982  0.441665  0.121793  0.994035  0.155075  0.924917  0.965999
# GENE 2  0.434987  0.867545  0.787186  0.622621  0.826302  0.996928  0.031609
# GENE 3  0.478854  0.116195  0.125316  0.972898  0.195309  0.255713  0.868732
# GENE 4  0.778970  0.955924  0.238693  0.169190  0.588628  0.437306  0.144298
# GENE 5  0.410908  0.859658  0.585744  0.673766  0.011771  0.698927  0.330423
# GENE 6  0.343810  0.431969  0.592287  0.434723  0.010042  0.476141  0.036275
# GENE 7  0.552575  0.181838  0.784813  0.554305  0.476306  0.885684  0.667885
# GENE 8  0.464085  0.514957  0.986269  0.976909  0.969668  0.799303  0.590892
# GENE 9  0.157444  0.542661  0.449113  0.664529  0.250759  0.762651  0.664968
#
# [10 rows x 50 columns]

# %%
nmf(df, 4)
# Out:
# (array([[ 0.        ,  0.        ,  0.88966522,  0.43117078],
#         [ 0.        ,  0.63577915,  0.        ,  1.00210344],
#         [ 0.04783688,  1.61503621,  0.05359246,  0.00208514],
#         [ 0.08974654,  0.        ,  0.35891301,  0.93405396],
#         [ 0.72549271,  0.24551341,  0.68767008,  0.        ],
#         [ 0.20129665,  0.631467  ,  0.68222921,  0.07748387],
#         [ 0.83609774,  0.30415069,  0.        ,  0.33957479],
#         [ 1.08145937,  0.        ,  0.33727281,  0.32215506],
#         [ 0.        ,  0.80713528,  0.74818987,  0.22496255],
#         [ 0.34684812,  0.50052855,  0.        ,  0.89889555]]),
#  array([[ 0.45156887,  0.17833174,  0.46472077,  0.16686948,  0.79338022,
#           0.43572334,  0.28782184,  0.45546502,  0.57550596,  0.78559226,
#           0.51732127,  0.06603205,  0.17703156,  0.18408007,  0.        ,
#           0.13318919,  0.5205911 ,  0.15458995,  0.12320543,  0.83588701,
#           0.1744662 ,  0.31106991,  0.11991538,  0.04629484,  0.51042876,
#           0.        ,  0.62517818,  0.08342689,  0.49219671,  0.28629556,
#           0.38954212,  0.27474102,  0.71755639,  0.02570987,  0.        ,
#           0.52326069,  0.34496273,  0.03244761,  0.0749836 ,  0.29040546,
#           0.40771368,  0.27398827,  0.17488922,  0.39290438,  0.31334729,
#           0.40817168,  0.10254335,  0.10445815,  0.38626509,  0.00421858],
#         [ 0.22779892,  0.18277157,  0.28098601,  0.0319797 ,  0.16915519,
#           0.13374997,  0.11943144,  0.        ,  0.        ,  0.3561539 ,
#           0.38764036,  0.        ,  0.22338158,  0.26140518,  0.55251133,
#           0.52413719,  0.        ,  0.44181107,  0.53649751,  0.01523737,
#           0.26564753,  0.50414267,  0.56293612,  0.16016979,  0.17898189,
#           0.1381523 ,  0.06723352,  0.4199827 ,  0.49618497,  0.51220348,
#           0.46911402,  0.52244179,  0.12588017,  0.30271796,  0.24948411,
#           0.09694443,  0.17602675,  0.22836285,  0.04454739,  0.05149994,
#           0.39511712,  0.44746662,  0.47859429,  0.21669947,  0.56468667,
#           0.48008015,  0.45205342,  0.39907423,  0.61215749,  0.0291911 ],
#         [ 0.31516998,  0.50615805,  0.00885703,  0.14144835,  0.20320727,
#           0.77676465,  0.91018579,  0.77620443,  0.49054681,  0.01809195,
#           0.37211783,  0.59711182,  0.52510074,  0.28895592,  0.12255044,
#           0.32867793,  0.2470671 ,  0.58586554,  0.65042811,  0.37684238,
#           0.19072262,  0.07317811,  0.48362002,  0.76199388,  0.        ,
#           0.11423879,  0.4057737 ,  0.25240733,  0.        ,  0.24378378,
#           0.2083099 ,  0.14841605,  0.09700166,  0.39433579,  0.82138932,
#           0.        ,  0.68424259,  0.46307739,  0.28549511,  0.31108854,
#           0.21214264,  0.68265245,  0.3905169 ,  0.36883831,  0.38339054,
#           0.37868235,  0.21408096,  0.48802813,  0.25677007,  0.33128537],
#         [ 0.        ,  0.28308984,  0.27815138,  0.64924429,  0.42430704,
#           0.1422811 ,  0.13283621,  0.47944356,  0.353275  ,  0.36055805,
#           0.1097438 ,  0.62626031,  0.50231481,  0.56637412,  0.71808594,
#           0.25357373,  0.59254397,  0.07922712,  0.08070214,  0.28841052,
#           0.43993565,  0.19970779,  0.19475971,  0.46212634,  0.39490447,
#           0.5241288 ,  0.13126039,  0.28278844,  0.43438316,  0.60770587,
#           0.03988549,  0.28752991,  0.35310725,  0.4962693 ,  0.16241753,
#           0.35064981,  0.11231749,  0.26153233,  0.50043707,  0.50974307,
#           0.27794151,  0.        ,  0.        ,  0.0818563 ,  0.00551601,
#           0.010526  ,  0.6876831 ,  0.        ,  0.37925153,  0.82051059]]),
#  4.164196228523434)

# %%
# make_heatmap_panel is in the ccba/library/ccba.py
# make_heatmap_panel calls plot_heatmap_panel, which is in the ccba/library/visualize.py
# make_heatmap_panel computes IC of each df's row and the ref (target).
# In the future, we can add other computation within this function so it can compute P-Val and FDR as well.
make_heatmap_panel(df, ref, ['IC', 'P-Val'])
# Out:
# /Users/Kwat/binf/ccba/library/ccba.py:62: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   dataframe.sort(sort_column, inplace=True)

# %%
# TODO: learn what to exclude
# Filter x and y


# TODO: understanding why intersect
# Get the intersection between x and y

if intersection:
    # Choose the rank of an SVD approximation via cross validation for x and y
    rank_x =
    rank_y =
    
    # Compute the |correlation| of x and y
    cor = abs()
    
    # TODO: understand where the numbers come from
    rank_x_XXX =
    rank_y_XXX =

    # TODO: 
    # Compute 2-dimensional kernel density estimation with an axis-aligned bivariate normal kernel, evaluated on a square grid.
    kernel_x =
    kernel_y =
    kernel_density =
    
    # TODO: understand math
    dx = 
    dy = 
    prob_xy = 
    prob_x = 
    prob_y = 
    entropy_xy = 
    entropy_x = 
    entropy_y = 
    prob_x = 
    prob_y = 
    mutual_information = 
    information_coefficient = 
else:
    information_coefficient = 0
    
print(information_coefficient) #return information_coefficient

# %%
### Make colorbar
fig = plt.figure(figsize=(8, 3))
ax1 = fig.add_axes([0.05, 0.80, 0.9, 0.15])
ax2 = fig.add_axes([0.05, 0.475, 0.9, 0.15])

# Set the colormap and norm to correspond to the data for which
# the colorbar will be used.
cmap = CMAP
norm = mpl.colors.Normalize(vmin=5, vmax=10)

# ColorbarBase derives from ScalarMappable and puts a colorbar
# in a specified axes, so it has everything needed for a
# standalone colorbar.  There are many more kwargs, but the
# following gives a basic continuous colorbar with ticks
# and labels.
cb1 = mpl.colorbar.ColorbarBase(ax1,
                                cmap=cmap,
                                norm=norm,
                                orientation='horizontal')
cb1.set_label('Unit')

# The length of the bounds array must be one greater than the length of the color list.
cmap = mpl.colors.ListedColormap([RED, PURPLE, GREEN])
# The bounds must be monotonically increasing.
bounds = [1, 2, 6, 8]
norm = mpl.colors.BoundaryNorm(bounds, cmap.N)

# Eextended ends to show the 'over' and 'under' value colors.
cmap.set_over(SILVER)
cmap.set_under(SILVER)
cb2 = mpl.colorbar.ColorbarBase(ax2,
                                cmap=cmap,
                                norm=norm,
                                boundaries=[bounds[0] - 3] + bounds + [bounds[-1] + 3],
                                extend='both',
                                extendfrac='auto',
                                ticks=bounds,
                                spacing='proportional',
                                orientation='horizontal')
cb2.set_label('Unit')

# %%
# Computation
def compute_association():
    """
    Compute pairwise association of x and y.
    """
    
def compute_conditional_association():
    """
    Compute pairwise association of x and y, given z.
    """
    
def compute_conditinal_mutual_information():
    """
    Compute the conditional mutual imnformation:
    I(X, Y | X) = H(X, Z) + H(Y, Z) - H(X, Y, Z) - H(Z).
    """
    
def normalize():
    """
    """
    
def train_basian_predictor():
    """
    XXX.
    """

def test_basian_predictor():
    """
    XXX.
    """
    
def compute_nonnegative_least_square():
    """
    """

def select_XXX():
    """
    XXX.
    """
    
def select_multiple_XXX():
    """
    Select multiple features form a given target XXX.
    """
    
def compute_area_under_regression_error_curve():
    """
    Compute area under the regression error curve (REC).
    This is the counter of the ROC for continuous target values.
    """
    
def compute_association():
    """
    Compute association between XXX and XXX.
    """
    
def compute_association_matrix():
    """
    Compute the distance between columns or rows across two matrices.
    """

# Onco GPS
def oncogps_define_states():
    """
    Compute the OncoGPS states by consensus clustering.
    """
    
def oncogps_map():
    """
    Map OncoGPS.
    """
    
def populate_map():
    """
    """
    
def create_components():
    """
    NMF projection.
    """

def select_k():
    """
    Select k for NMF.
    """
    
def nmf():
    """
    NMF.
    """
    
# Visualization
def get_overlap():
    """
    XXX.
    """

def explore():
    """
    XXX.
    """
    
def convert_maf_to_gct():
    """
    XXX.
    """

def generate_association_matrix():
    """
    XXX.
    """
    
def plot_mutual_information():
    """
    """
    def read_cls():
    """
    Read a .cls and XXX.
    """
    
# File manipulation

def read_gmt():
    """
    Read a .gmt and XXX.
    """

def filter_matrix():
    """
    Filter a subset of features and samples.
    """
    
def subset_phenotype():
    """
    XXX.
    """
    
def subset_feature():
    """
    XXX.
    """
    
def match_and_merge():
    """
    XXX.
    """
