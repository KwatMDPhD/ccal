# %% [markdown]
# # Jupyter and Python Interactive Graphics

# %%
# Author: Vachan Vadmal

# Table of Contents 
# Using Bokeh

# %% [markdown]
# <h1 fontsize=20>
# Table of Contents
# </h1>

# %% [markdown]
# 1. Bokeh Scatter Plot

# %% [markdown]
# # Bokeh Scatter Plot

# %%
# This little example shows how to create a scatter plot with random coordinates and random descriptions that you
# can then see on the plot by using the hover tool in Bokeh

from bokeh.plotting import figure, output_file, show, ColumnDataSource
from bokeh.models import HoverTool
from bokeh.io import output_notebook

import numpy as np
import random

x = np.random.rand(10)
y = np.random.rand(10)

strgs = []
for i in range(10): 
    strgs.append("".join(random.choice("agggeagabfda") for _ in range(5)))
    
datasource = ColumnDataSource(data=dict(x = np.random.rand(10), y = np.random.rand(10), desc=strgs))

hover = HoverTool(
        tooltips=[
            ("index", "$index"),
            ("(x,y)", "($x, $y)"),
            ('va', '@desc')
        ]
    )

output_notebook()
p = figure(plot_width=400, plot_height=400,
           title="Mouse over the dots")

p.circle('x', 'y', size=10, alpha=0, source=datasource)
p.add_tools(hover)

show(p)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="dbfb0d98-b672-4e91-9154-b46c4cc6f04b">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="5a342c78-f603-48d2-87d9-0fb3155ebc0f"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5a342c78-f603-48d2-87d9-0fb3155ebc0f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5a342c78-f603-48d2-87d9-0fb3155ebc0f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"9f19e425-e401-4512-899e-bbe2156581f6":{"roots":{"references":[{"attributes":{"plot":{"id":"762d0975-7384-4d0f-82c2-dd88a53dbf87","subtype":"Figure","type":"Plot"}},"id":"ffd550e2-e0b0-4314-a3ff-1824cc25038b","type":"PreviewSaveTool"},{"attributes":{"formatter":{"id":"71296048-7e93-419a-a10c-67d5b1d7a53b","type":"BasicTickFormatter"},"plot":{"id":"6e325767-94ac-46ca-bb88-3bdf65c7cf14","subtype":"Figure","type":"Plot"},"ticker":{"id":"43b758d0-4673-44aa-bbde-f1fd53529173","type":"BasicTicker"}},"id":"eaafe160-dea8-4632-a1b6-dfb12f693f4a","type":"LinearAxis"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"cad1227d-bba4-41d2-b6ee-666d47a0f9ee","type":"Circle"},{"attributes":{"fill_alpha":{"value":0},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"42acc7d7-14f9-4620-bb88-a80990e473ca","type":"Circle"},{"attributes":{"overlay":{"id":"a6b65e8f-17c5-4711-847b-a1ee3f8a24d5","type":"BoxAnnotation"},"plot":{"id":"204241b6-9a33-449d-b759-c772b17cbf10","subtype":"Figure","type":"Plot"}},"id":"e11f39f9-a222-45d7-97e9-ebdcf87e485c","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"6e325767-94ac-46ca-bb88-3bdf65c7cf14","subtype":"Figure","type":"Plot"}},"id":"34e0f329-fde3-4541-8302-7000a3a81f17","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"8ec460e9-8ada-49d4-ad33-2393bfa666c5","type":"BoxAnnotation"},"plot":{"id":"9bfb9914-d72b-4b84-b0bd-1b7fcc3cb34c","subtype":"Figure","type":"Plot"}},"id":"0af795d1-6c9b-4c43-afa6-c48fa36294a9","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"b25056c2-aec7-46b1-a6b5-fa2b17f8a32e","subtype":"Figure","type":"Plot"},"ticker":{"id":"2523fa9a-5a2a-4911-a6e6-1aae6e773d15","type":"BasicTicker"}},"id":"eb789acb-13ac-454f-b8e9-803bef3b6a2f","type":"Grid"},{"attributes":{},"id":"195aefe4-13d5-4fe3-beed-cb03d7a97803","type":"ToolEvents"},{"attributes":{"below":[{"id":"52bbd151-d09b-4862-9234-3dae589f77d9","type":"LinearAxis"}],"left":[{"id":"ddb20a0b-7939-41e1-8b67-ce2cccca6018","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"52bbd151-d09b-4862-9234-3dae589f77d9","type":"LinearAxis"},{"id":"4788bf3c-b8d5-437b-a131-221027dbfe42","type":"Grid"},{"id":"ddb20a0b-7939-41e1-8b67-ce2cccca6018","type":"LinearAxis"},{"id":"2972a713-e0e4-47b0-815c-792a3386a201","type":"Grid"},{"id":"635fbcae-46b2-482d-9e35-5a207039a560","type":"BoxAnnotation"},{"id":"e75ea59d-bd8c-4e52-b828-ac529e056893","type":"GlyphRenderer"}],"title":"Mouse over the dots","tool_events":{"id":"195aefe4-13d5-4fe3-beed-cb03d7a97803","type":"ToolEvents"},"tools":[{"id":"62792161-988e-4b79-839b-c2d2036fa822","type":"PanTool"},{"id":"32ff8c7b-8588-4cc4-a239-72b1e42a69ca","type":"WheelZoomTool"},{"id":"7778bc0a-a2f2-4130-a5c8-d6ac15749bac","type":"BoxZoomTool"},{"id":"17bc4fe6-a124-4116-aa6d-3f585238d7ef","type":"PreviewSaveTool"},{"id":"228ed02c-bd78-41d5-9840-3b563b171d26","type":"ResizeTool"},{"id":"6384cb3c-faf3-4487-a199-9fdc733bbcbf","type":"ResetTool"},{"id":"51797360-6ded-40be-93e9-fd5ff2cfc874","type":"HelpTool"},{"id":"0e461452-dadf-4e76-8a73-93abef340580","type":"HoverTool"}],"x_range":{"id":"ac23d627-528e-4896-9626-78d44400e552","type":"DataRange1d"},"y_range":{"id":"283d5c31-b6f6-43ec-a692-159d6efe37ac","type":"DataRange1d"}},"id":"6e6f8407-41dc-412d-bb41-b92064cd0e76","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"6e6f8407-41dc-412d-bb41-b92064cd0e76","subtype":"Figure","type":"Plot"}},"id":"62792161-988e-4b79-839b-c2d2036fa822","type":"PanTool"},{"attributes":{"plot":{"id":"b48fe308-8faf-4485-a488-b18ea85cdb19","subtype":"Figure","type":"Plot"}},"id":"ee7489ef-4639-4422-9f9e-46ec375d3b6e","type":"PanTool"},{"attributes":{"plot":{"id":"f833ad96-1fd4-42d5-9a06-02c36fcab5a5","subtype":"Figure","type":"Plot"}},"id":"3d8a249a-6d70-4d6b ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[15]</strong>&gt;</code></p>
